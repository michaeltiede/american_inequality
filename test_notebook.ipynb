# %%
# Step-by-step testing notebook for county comparison logic

import pandas as pd
import numpy as np
import pickle
from preprocessed_data import features, racial_features, get_pool_and_scaled

# --------------------------
# Inputs
# --------------------------
state_input = "South Dakota"
county_input = "Oglala Lakota"
variable_input = "Income"

# %% [markdown]
# | Left Behind County                  | Mirror Counties                      |
# |------------------------------------|-------------------------------------|
# | Imperial County, California        | Guadalupe County, Texas              |
# | Oglala Lakota County, South Dakota | Big Horn County, Montana            |
# | Holmes County, Mississippi         | Brunswick County, Virginia              |
# | McDowell County, West Virginia     | Yancey County, North Carolina
# | Bronx County, New York             | Fulton County, Georgia               |

# %%
df = pd.read_csv("preprocessed_data.csv")

# %%
# Step 1: Filter selected county
selected_row = df[(df['State'] == state_input) & (df['County'] == county_input)]
if selected_row.empty:
    raise ValueError(f"No data found for {county_input}, {state_input}")

population_value = selected_row['Population'].values[0]
print(f"Selected county: {county_input}, Population: {population_value}")
selected_row
# Out:
# Selected county: Oglala Lakota, Population: 13519
#        FIPS         State         County  Population  % Black  \
# 2413  46102  South Dakota  Oglala Lakota       13519      0.3
#
#       % American Indian or Alaska Native  % Asian  \
# 2413                                89.5      0.3
#
#       % Native Hawaiian or Other Pacific Islander  % Hispanic  \
# 2413                                          0.1         5.4
#
#       % Non-Hispanic White  ...  Arts, entertainment, and recreation  \
# 2413                   4.9  ...                               0.0581
#
#       Accommodation and food services  \
# 2413                             0.03
#
#       Other services, except public administration  Public administration  \
# 2413                                        0.0206                 0.1535
#
#             Top 1 industry                     Top 2 industry  \
# 2413  Educational services  Health care and social assistance
#
#              Top 1 Industry String                      Top 2 Industry String  \
# 2413  Educational services: 23.35%  Health care and social assistance: 15.51%
#
#       population_percentile  More Info
# 2413              30.544066        NaN
#
# [1 rows x 42 columns]

# %%
print('Population' in features)
# Out:
# True

# %%
# --------------------------
# Step 2: Load scaler and weights
# --------------------------
with open('scaler.pkl', 'rb') as f:
    scaler = pickle.load(f)

with open('weights.pkl', 'rb') as f:
    all_weights = pickle.load(f)

# %%
# --------------------------
# Step 3: Scale features
# --------------------------
selected_scaled = scaler.transform(selected_row[features]).flatten()
df_scaled = scaler.transform(df[features])
print("Scaled shapes:", df_scaled.shape, selected_scaled.shape)
# Out:
# Scaled shapes: (3143, 28) (28,)

# %%
# --------------------------
# Step 4: Get weighted pool
# --------------------------
df_pool, df_scaled_pool, weights = get_pool_and_scaled(
    population_value, df, scaler, features, racial_features, all_weights
)
print("Pool shape:", df_pool.shape)
# Out:
# Pool shape: (3143, 42)

# %%
# --------------------------
# Step 5: Compute weighted Euclidean distances
# --------------------------
distances = np.linalg.norm((df_scaled_pool - selected_scaled) * weights, axis=1)
print("Distances shape:", distances.shape)
# Out:
# Distances shape: (3143,)

# %%
# --------------------------
# Step 6: Get k nearest neighbors
# --------------------------
k = 200
indices = np.argsort(distances)[:k]
similar_counties = df_pool.iloc[indices].copy()
print("Top k similar counties shape:", similar_counties.shape)
print(similar_counties[['State','County','Population']].head(10))
# Out:
# Top k similar counties shape: (200, 42)
#              State         County  Population
# 2413  South Dakota  Oglala Lakota       13519
# 2370  South Dakota        Buffalo        1861
# 2030  North Dakota        Rolette       11933
# 2422  South Dakota           Todd        9220
# 1616       Montana        Glacier       13681
# 2382  South Dakota          Dewey        5140
# 97         Arizona         Apache       65432
# 1741      Nebraska       Thurston        6507
# 1600       Montana       Big Horn       12851
# 83          Alaska       Kusilvak        8278

# %%
# --------------------------
# Step 7: Remove same state
# --------------------------
similar_counties = similar_counties[similar_counties['State'] != state_input]
print("After state filter shape:", similar_counties.shape)
similar_counties
# Out:
# After state filter shape: (182, 42)
#        FIPS         State             County  Population  % Black  \
# 2030  38079  North Dakota            Rolette       11933      0.5
# 1616  30035       Montana            Glacier       13681      0.3
# 97     4001       Arizona             Apache       65432      0.6
# 1741  31173      Nebraska           Thurston        6507      0.5
# 1600  30003       Montana           Big Horn       12851      0.4
# ...     ...           ...                ...         ...      ...
# 2958  53009    Washington            Clallam       77805      0.9
# 1308  26153      Michigan        Schoolcraft        8188      0.4
# 85     2170        Alaska  Matanuska-Susitna      113325      1.2
# 1207  24029      Maryland               Kent       19320     13.6
# 2807  50001       Vermont            Addison       37578      1.2
#
#       % American Indian or Alaska Native  % Asian  \
# 2030                                77.7      0.3
# 1616                                65.0      0.4
# 97                                  73.4      0.5
# 1741                                58.5      0.8
# 1600                                66.7      0.8
# ...                                  ...      ...
# 2958                                 5.8      2.1
# 1308                                 9.3      0.3
# 85                                   7.0      1.7
# 1207                                 0.5      1.5
# 2807                                 0.3      1.9
#
#       % Native Hawaiian or Other Pacific Islander  % Hispanic  \
# 2030                                          0.0         2.4
# 1616                                          0.0         3.6
# 97                                            0.1         7.2
# 1741                                          0.1         8.6
# 1600                                          0.0         6.6
# ...                                           ...         ...
# 2958                                          0.2         7.6
# 1308                                          0.0         1.7
# 85                                            0.5         5.8
# 1207                                          0.1         5.0
# 2807                                          0.0         2.6
#
#       % Non-Hispanic White  ...  Arts, entertainment, and recreation  \
# 2030                  17.5  ...                               0.0324
# 1616                  29.4  ...                               0.0304
# 97                    18.9  ...                               0.0166
# 1741                  34.3  ...                               0.0529
# 1600                  25.7  ...                               0.0191
# ...                    ...  ...                                  ...
# 2958                  81.3  ...                               0.0342
# 1308                  84.8  ...                               0.0093
# 85                    77.3  ...                               0.0157
# 1207                  77.9  ...                               0.0219
# 2807                  92.2  ...                               0.0225
#
#       Accommodation and food services  \
# 2030                           0.0259
# 1616                           0.0866
# 97                             0.0577
# 1741                           0.0460
# 1600                           0.0924
# ...                               ...
# 2958                           0.0776
# 1308                           0.0983
# 85                             0.0555
# 1207                           0.0566
# 2807                           0.0476
#
#       Other services, except public administration  Public administration  \
# 2030                                        0.0150                 0.0972
# 1616                                        0.0270                 0.1533
# 97                                          0.0193                 0.1149
# 1741                                        0.0290                 0.1592
# 1600                                        0.0248                 0.1155
# ...                                            ...                    ...
# 2958                                        0.0620                 0.0817
# 1308                                        0.0362                 0.0865
# 85                                          0.0492                 0.0915
# 1207                                        0.0590                 0.0604
# 2807                                        0.0452                 0.0363
#
#                          Top 1 industry                     Top 2 industry  \
# 2030               Educational services  Health care and social assistance
# 1616               Educational services              Public administration
# 97    Health care and social assistance               Educational services
# 1741  Health care and social assistance              Public administration
# 1600  Health care and social assistance               Educational services
# ...                                 ...                                ...
# 2958  Health care and social assistance                       Retail trade
# 1308  Health care and social assistance                      Manufacturing
# 85    Health care and social assistance                       Construction
# 1207               Educational services                       Retail trade
# 2807               Educational services  Health care and social assistance
#
#                           Top 1 Industry String  \
# 2030               Educational services: 21.53%
# 1616               Educational services: 16.09%
# 97    Health care and social assistance: 22.68%
# 1741  Health care and social assistance: 16.61%
# 1600  Health care and social assistance: 14.92%
# ...                                         ...
# 2958  Health care and social assistance: 16.99%
# 1308  Health care and social assistance: 14.95%
# 85     Health care and social assistance: 15.4%
# 1207               Educational services: 14.63%
# 2807               Educational services: 15.74%
#
#                           Top 2 Industry String  population_percentile  \
# 2030  Health care and social assistance: 17.99%              27.362393
# 1616              Public administration: 15.33%              30.766783
# 97                 Educational services: 17.64%              73.687560
# 1741              Public administration: 15.91%              14.237989
# 1600               Educational services: 14.77%              29.462297
# ...                                         ...                    ...
# 2958                       Retail trade: 12.91%              76.710150
# 1308                      Manufacturing: 14.36%              18.485523
# 85                         Construction: 12.86%              82.596246
# 1207                       Retail trade: 11.78%              40.820872
# 2807  Health care and social assistance: 13.25%              60.642698
#
#       More Info
# 2030        NaN
# 1616        NaN
# 97          NaN
# 1741        NaN
# 1600        NaN
# ...         ...
# 2958        NaN
# 1308        NaN
# 85          NaN
# 1207        NaN
# 2807        NaN
#
# [182 rows x 42 columns]

# %%
# --------------------------
# Step 8: Apply percentile filter for small counties
# --------------------------
if population_value <= 700_000:
    selected_percentile = selected_row['population_percentile'].values[0]
    percentile_min = selected_percentile - 3
    percentile_max = selected_percentile + 3
    similar_counties = similar_counties[
        (similar_counties['population_percentile'] >= percentile_min) &
        (similar_counties['population_percentile'] <= percentile_max)
    ]
print("After percentile filter shape:", similar_counties.shape)
# Out:
# After percentile filter shape: (13, 42)

# %%
# --------------------------
# Step 9: Rank by Income, exclude selected county
# --------------------------
ranked_counties = similar_counties.sort_values(by='Income', ascending=False)
ranked_counties = ranked_counties[ranked_counties.index != index]
top_10_counties = ranked_counties.head(10)
print("Top 10 counties shape:", top_10_counties.shape)
# Out:
# Top 10 counties shape: (10, 42)

# %%
# --------------------------
# Step 10: Add links (like More Info column)
# --------------------------
def make_compare_link(original_fips, compare_fips):
    original_fips = str(original_fips).zfill(5)
    compare_fips = str(compare_fips).zfill(5)
    return f"https://www.countyhealthrankings.org/health-data/compare-counties?year=2025&compareCounties={original_fips},{compare_fips}"

original_fips = selected_row['FIPS'].values[0]
top_10_counties['More Info'] = top_10_counties['FIPS'].apply(lambda fips: f"[Link]({make_compare_link(original_fips, fips)})")
# Out:
# C:\Users\miket\AppData\Local\Temp\ipykernel_17568\1215309043.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_10_counties['More Info'] = top_10_counties['FIPS'].apply(lambda fips: f"[Link]({make_compare_link(original_fips, fips)})")

# %%
# --------------------------
# Step 11: Display top 10 with same columns as dashboard
# --------------------------
display_columns = ['State', 'County', 'Population', 'Income',
                   'Top 1 Industry String','Top 2 Industry String',
                   '% Rural', '% Black', '% American Indian or Alaska Native',
                   '% Asian', '% Native Hawaiian or Other Pacific Islander', '% Hispanic', 'More Info']

top_10_counties[display_columns]
# Out:
#                State             County  Population   Income  \
# 81            Alaska  Ketchikan Gateway       13741  82648.0
# 931           Kansas            Jackson       13286  70445.0
# 2181        Oklahoma             Murray       13672  60307.0
# 1977  North Carolina              Swain       13967  55462.0
# 1516        Missouri               Dent       14467  52945.0
# 2796            Utah           San Juan       14359  50452.0
# 1600         Montana           Big Horn       12851  49113.0
# 2149        Oklahoma              Craig       14123  48922.0
# 1616         Montana            Glacier       13681  46270.0
# 2134        Oklahoma              Atoka       14262  46160.0
#
#                           Top 1 Industry String  \
# 81    Health care and social assistance: 16.49%
# 931                       Manufacturing: 14.39%
# 2181                       Retail trade: 17.05%
# 1977  Health care and social assistance: 14.35%
# 1516  Health care and social assistance: 18.98%
# 2796               Educational services: 19.08%
# 1600  Health care and social assistance: 14.92%
# 2149  Health care and social assistance: 17.77%
# 1616               Educational services: 16.09%
# 2134                       Retail trade: 12.48%
#
#                             Top 2 Industry String  % Rural  % Black  \
# 81                            Retail trade: 9.91%     14.1      1.0
# 931     Health care and social assistance: 14.02%    100.0      1.0
# 2181    Health care and social assistance: 12.17%     65.1      1.8
# 1977  Arts, entertainment, and recreation: 11.78%    100.0      1.4
# 1516                 Educational services: 12.74%     67.5      0.6
# 2796    Health care and social assistance: 15.28%    100.0      0.4
# 1600                 Educational services: 14.77%    100.0      0.4
# 2149                         Retail trade: 10.92%     64.1      2.8
# 1616                Public administration: 15.33%    100.0      0.3
# 2134    Health care and social assistance: 12.46%    100.0      5.3
#
#       % American Indian or Alaska Native  % Asian  \
# 81                                  14.3      8.6
# 931                                  8.8      0.6
# 2181                                14.6      0.7
# 1977                                30.6      0.8
# 1516                                 1.2      0.8
# 2796                                47.1      0.6
# 1600                                66.7      0.8
# 2149                                21.9      1.4
# 1616                                65.0      0.4
# 2134                                15.3      0.9
#
#       % Native Hawaiian or Other Pacific Islander  % Hispanic  \
# 81                                            0.4         5.8
# 931                                           0.0         5.7
# 2181                                          0.1         7.6
# 1977                                          0.1         7.3
# 1516                                          0.1         2.2
# 2796                                          0.1         6.7
# 1600                                          0.0         6.6
# 2149                                          0.2         5.2
# 1616                                          0.0         3.6
# 2134                                          0.0         4.6
#
#                                               More Info
# 81    [Link](https://www.countyhealthrankings.org/he...
# 931   [Link](https://www.countyhealthrankings.org/he...
# 2181  [Link](https://www.countyhealthrankings.org/he...
# 1977  [Link](https://www.countyhealthrankings.org/he...
# 1516  [Link](https://www.countyhealthrankings.org/he...
# 2796  [Link](https://www.countyhealthrankings.org/he...
# 1600  [Link](https://www.countyhealthrankings.org/he...
# 2149  [Link](https://www.countyhealthrankings.org/he...
# 1616  [Link](https://www.countyhealthrankings.org/he...
# 2134  [Link](https://www.countyhealthrankings.org/he...

# %%
print("Features to scale:", features)
print("Columns in df:", df.columns.tolist())
# Out:
# Features to scale: ['% Black', '% American Indian or Alaska Native', '% Asian', '% Native Hawaiian or Other Pacific Islander', '% Hispanic', '% Non-Hispanic White', 'Population', '% Rural', 'Agriculture, forestry, fishing and hunting', 'Mining, quarrying, and oil and gas extraction', 'Construction', 'Manufacturing', 'Wholesale trade', 'Retail trade', 'Transportation and warehousing', 'Utilities', 'Information', 'Finance and insurance', 'Real estate and rental and leasing', 'Professional, scientific, and technical services', 'Management of companies', 'Administrative and support and waste management services', 'Educational services', 'Health care and social assistance', 'Arts, entertainment, and recreation', 'Accommodation and food services', 'Other services, except public administration', 'Public administration']
# Columns in df: ['FIPS', 'State', 'County', 'Population', '% Black', '% American Indian or Alaska Native', '% Asian', '% Native Hawaiian or Other Pacific Islander', '% Hispanic', '% Non-Hispanic White', '% Rural', 'Life Expectancy', 'Income', 'Upward mobility', 'Longitude', 'Latitude', 'Agriculture, forestry, fishing and hunting', 'Mining, quarrying, and oil and gas extraction', 'Construction', 'Manufacturing', 'Wholesale trade', 'Retail trade', 'Transportation and warehousing', 'Utilities', 'Information', 'Finance and insurance', 'Real estate and rental and leasing', 'Professional, scientific, and technical services', 'Management of companies', 'Administrative and support and waste management services', 'Educational services', 'Health care and social assistance', 'Arts, entertainment, and recreation', 'Accommodation and food services', 'Other services, except public administration', 'Public administration', 'Top 1 industry', 'Top 2 industry', 'Top 1 Industry String', 'Top 2 Industry String', 'population_percentile', 'More Info']
